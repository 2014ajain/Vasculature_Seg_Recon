# %%
import os
os.environ['nnUNet_raw'] = "/home/ameen/Aseem_project/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/home/ameen/Aseem_project/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/home/ameen/Aseem_project/nnUNet_results"
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
from nnunetv2.dataset_conversion.generate_dataset_json import generate_dataset_json
from nnunetv2.paths import nnUNet_raw
from batchgenerators.utilities.file_and_folder_operations import *
print(nnUNet_raw)
# Out:
# /home/ameen/Aseem_project/nnUNet_raw

# %%
dataset_name = 'Dataset147_Vas'
generate_dataset_json(join(nnUNet_raw, dataset_name), {0: 'R', 1: 'G', 2: 'B'}, {'background': 0, 'road': 1}, 41, '.png', dataset_name=dataset_name)

# %%
# !nnUNetv2_plan_and_preprocess -d 147 --verify_dataset_integrity
# Out:
# Fingerprint extraction...
# Dataset147_Vas
# Using <class 'nnunetv2.imageio.natural_image_reager_writer.NaturalImage2DIO'> as reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Using <class 'nnunetv2.imageio.natural_image_reager_writer.NaturalImage2DIO'> as reader/writer
# 100%|████████████████████████████████████████| 257/257 [00:01<00:00, 189.18it/s]
# Experiment planning...
# 2D U-Net configuration:
# ...

# %%
for i in [0,1,2,4]:
    # !nnUNetv2_train 147 2d {i} --npz
# Out:
# Using device: cuda:0
# 2023-05-10 04:38:51.142464: failed to log:  (<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x7f25db1c0800>)
# 2023-05-10 04:38:51.142464: failed to log:  (<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x7f25db1c0800>)
# 2023-05-10 04:38:51.142464: failed to log:  (<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x7f25db1c0800>)
# 2023-05-10 04:38:51.142464: failed to log:  (<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x7f25db1c0800>)
# 2023-05-10 04:38:51.142464: failed to log:  (<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x7f25db1c0800>)
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# ...

# %%
# !nnUNetv2_find_best_configuration 147
# Out:
# Configuration 3d_fullres not found in plans nnUNetPlans.
# Inferred plans file: /home/ameen/Aseem_project/nnUNet_preprocessed/Dataset147_Vas/nnUNetPlans.json.
# Configuration 3d_lowres not found in plans nnUNetPlans.
# Inferred plans file: /home/ameen/Aseem_project/nnUNet_preprocessed/Dataset147_Vas/nnUNetPlans.json.
# Configuration 3d_cascade_fullres not found in plans nnUNetPlans.
# Inferred plans file: /home/ameen/Aseem_project/nnUNet_preprocessed/Dataset147_Vas/nnUNetPlans.json.
#
# ***All results:***
# nnUNetTrainer__nnUNetPlans__2d: 0.7418328068674912
#
# *Best*: nnUNetTrainer__nnUNetPlans__2d: 0.7418328068674912
#
# ***Determining postprocessing for best model/ensemble***
# Removing all but the largest foreground region did not improve results!
#
# ***Run inference like this:***
#
# nnUNetv2_predict -d Dataset147_Vas -i INPUT_FOLDER -o OUTPUT_FOLDER -f  0 1 2 3 4 -tr nnUNetTrainer -c 2d -p nnUNetPlans
#
# ***Once inference is completed, run postprocessing like this:***
#
# ...

# %%
inputfolder="/home/ameen/Aseem_project/Vasculardata"
outputfolder="/home/ameen/Aseem_project/vascularout"

# !nnUNetv2_predict -d Dataset147_Vas -i {inputfolder} -o {outputfolder} -f  0 1 2 3 4 -tr nnUNetTrainer -c 2d -p nnUNetPlans
# Out:
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# There are 1320 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1320 cases that I would like to predict
# using pin_memory on device 0
#
# Predicting vas_0:
# perform_everything_on_gpu: True
# Prediction done, transferring to CPU if needed
# sending off prediction to background worker for resampling and export
# done with vas_0
#
# Predicting vas_1:
# perform_everything_on_gpu: True
# Prediction done, transferring to CPU if needed
# sending off prediction to background worker for resampling and export
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.13.0+cu116

# %%
import torch

print(torch.cuda.is_available())


print(torch.cuda.device_count())


print(torch.cuda.current_device())
# Out:
# True
# 2
# 0
